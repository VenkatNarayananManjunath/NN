# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkatNarayananManjunath/NN/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
yolo = YOLO('yolov8n.pt')
image_path = r'/content/Jayanarayan Manjunath -  C16170359.jpg'  # Updated to the path of the uploaded file
results = yolo(image_path)
for r in results:
    im_array = r.plot()     # plot a BGR numpy array of predictions
    # OpenCV loads images as BGR, but cv2_imshow expects RGB for correct color display.
    im_rgb = cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)
    cv2_imshow(im_rgb)
# Out:
# ...
#
# image 1/1 /content/Jayanarayan Manjunath -  C16170359.jpg: 640x544 1 person, 187.8ms
# Speed: 4.3ms preprocess, 187.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
# <PIL.Image.Image image mode=RGB size=423x510>

# %%
from google.colab import files
uploaded = files.upload()
for filename in uploaded.keys():
    print(f'Uploaded file "{filename}" to /content/{filename}')
# Out:
#      <input type="file" id="files-7bce15f5-347e-495a-a63a-1e1a80b4338b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bce15f5-347e-495a-a63a-1e1a80b4338b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
